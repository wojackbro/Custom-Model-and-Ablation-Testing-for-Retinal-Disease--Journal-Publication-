# %%
# !pip install pandas

# %%
# !pip install matplotlib

# %%
# !pip install seaborn

# %%
# !pip install opencv-python

# %%
# !pip install scikit-learn

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import keras
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
import tensorflow as tf
import matplotlib.cm as cm
import cv2
import math

# %%
from keras.applications.vgg16 import VGG16
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Input
from keras.models import Model
from keras.layers import Dense
from keras.optimizers import Adam
from sklearn import model_selection
from sklearn.model_selection import train_test_split, KFold, cross_val_score, StratifiedKFold, GridSearchCV
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, make_scorer, accuracy_score, classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.imagenet_utils import preprocess_input
from tensorflow.keras import layers, models
from tensorflow.keras.metrics import Precision, Recall
from keras.callbacks import ReduceLROnPlateau
# from sklearn.metrics import classification_report

# %%
input_dir = "D:/Thesis dataset/FINAL DATASET/4k_UNIQUE_Test/"
train_dir = input_dir +"train/"
test_dir = input_dir +"test/"

# %%
# Data Augmentation
train_datagen = ImageDataGenerator(
      rescale=1./255,
       rotation_range=10,
       width_shift_range=0.1,
       height_shift_range=0.1,
       shear_range=0.1,
       zoom_range=0.1,
       #horizontal_flip=True,
       fill_mode='nearest',
      validation_split=0.2
)

test_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(224, 224),
        batch_size=64,
        class_mode='categorical',
        subset='training'

)
test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(224, 224),
        batch_size=64,
        class_mode='categorical',
        shuffle = False
)
validation_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(224, 224),
        batch_size=64,
        class_mode='categorical',
        subset='validation'
)
#class_weights = {0: 1.0, 1: 3.43, 2: 4.61, 3: 1.41}
# Out:
# Found 63588 images belonging to 4 classes.
# Found 4000 images belonging to 4 classes.
# Found 15896 images belonging to 4 classes.

# %%
model = Sequential([
    # Input layer
    tf.keras.layers.InputLayer(input_shape=(224, 224, 3)),

    # Conv block 1
    Conv2D(16, kernel_size=(3,3), padding='same', activation='relu', name="Conv_1-1"),
    MaxPooling2D(pool_size=(2,2), strides=2),

    # Conv block 2
    Conv2D(16, kernel_size=(3,3), padding='same', activation='relu', name="Conv_2-1"),
    Conv2D(32, kernel_size=(3,3), padding='same', activation='relu', name="Conv_2-2"),
    MaxPooling2D(pool_size=(2,2), strides=2),

    # Conv block 3
    Conv2D(32, kernel_size=(3,3), padding='same', activation='relu', name="Conv_3-1"),
    Conv2D(32, kernel_size=(3,3), padding='same', activation='relu', name="Conv_3-2"),
    Conv2D(48, kernel_size=(3,3), padding='same', activation='relu', name="Conv_3-3"),
    MaxPooling2D(pool_size=(2,2), strides=2),

    # Conv block 4
    Conv2D(48, kernel_size=(3,3), padding='same', activation='relu', name="Conv_4-1"),
    Conv2D(48, kernel_size=(3,3), padding='same', activation='relu', name="Conv_4-2"),
    Conv2D(64, kernel_size=(3,3), padding='same', activation='relu', name="Conv_4-3"),
    Conv2D(64, kernel_size=(3,3), padding='same', activation='relu', name="Conv_4-4"),
    MaxPooling2D(pool_size=(2,2), strides=2),
    
    #conv block 5
    Conv2D(64, kernel_size=(3,3), padding='same', activation='relu', name="Conv_5-1"),
    Conv2D(96, kernel_size=(3,3), padding='same', activation='relu', name="Conv_5-2"),
    MaxPooling2D(pool_size=(2,2), strides=2),

    # Flatten
    Flatten(),

    # Fully connected layers
    Dense(512, activation='relu'),
    Dense(512, activation='relu'),
    #Dense(4, activation='relu'),
    #Dropout(0.4),

    # Output layer
    Dense(4, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Conv_1-1 (Conv2D)           (None, 224, 224, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 16)     0
#  )
#
#  Conv_2-1 (Conv2D)           (None, 112, 112, 16)      2320
#
#  Conv_2-2 (Conv2D)           (None, 112, 112, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 32)       0
#  2D)
#
#  Conv_3-1 (Conv2D)           (None, 56, 56, 32)        9248
#
#  Conv_3-2 (Conv2D)           (None, 56, 56, 32)        9248
#
#  Conv_3-3 (Conv2D)           (None, 56, 56, 48)        13872
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 48)       0
#  2D)
#
#  Conv_4-1 (Conv2D)           (None, 28, 28, 48)        20784
#
#  Conv_4-2 (Conv2D)           (None, 28, 28, 48)        20784
#
#  Conv_4-3 (Conv2D)           (None, 28, 28, 64)        27712
#
#  Conv_4-4 (Conv2D)           (None, 28, 28, 64)        36928
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  Conv_5-1 (Conv2D)           (None, 14, 14, 64)        36928
#
#  Conv_5-2 (Conv2D)           (None, 14, 14, 96)        55392
#
#  max_pooling2d_4 (MaxPooling  (None, 7, 7, 96)         0
#  2D)
#
#  flatten (Flatten)           (None, 4704)              0
#
#  dense (Dense)               (None, 512)               2408960
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dense_2 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 2,911,972
# Trainable params: 2,911,972
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow_addons as tfa
lr = 0.001
model.compile(
        loss='categorical_crossentropy',
        optimizer=Adam(lr=lr),
        metrics=['accuracy', tfa.metrics.F1Score(num_classes=4), Precision(), Recall()]
    )

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6, verbose=1)

# %%
history = model.fit_generator(
    train_generator,
#     steps_per_epoch = 50,
    epochs = 50,
    validation_data = validation_generator,
    #validation_steps = 50
    #class_weight = class_weights
    callbacks = [reduce_lr]
)
# Out:
# Epoch 1/50
# 994/994 [==============================] - 738s 738ms/step - loss: 0.7046 - accuracy: 0.7234 - f1_score: 0.5794 - precision: 0.8292 - recall: 0.6032 - val_loss: 0.3179 - val_accuracy: 0.8943 - val_f1_score: 0.8281 - val_precision: 0.9078 - val_recall: 0.8834 - lr: 0.0010
# Epoch 2/50
# 994/994 [==============================] - 708s 713ms/step - loss: 0.2766 - accuracy: 0.9089 - f1_score: 0.8619 - precision: 0.9162 - recall: 0.9017 - val_loss: 0.2647 - val_accuracy: 0.9168 - val_f1_score: 0.8571 - val_precision: 0.9224 - val_recall: 0.9113 - lr: 0.0010
# Epoch 3/50
# 994/994 [==============================] - 694s 699ms/step - loss: 0.2199 - accuracy: 0.9272 - f1_score: 0.8908 - precision: 0.9316 - recall: 0.9227 - val_loss: 0.2293 - val_accuracy: 0.9309 - val_f1_score: 0.8942 - val_precision: 0.9365 - val_recall: 0.9280 - lr: 0.0010
# Epoch 4/50
# 994/994 [==============================] - 700s 704ms/step - loss: 0.1962 - accuracy: 0.9356 - f1_score: 0.9042 - precision: 0.9394 - recall: 0.9322 - val_loss: 0.1795 - val_accuracy: 0.9430 - val_f1_score: 0.9150 - val_precision: 0.9463 - val_recall: 0.9414 - lr: 0.0010
# Epoch 5/50
# 994/994 [==============================] - 701s 705ms/step - loss: 0.1795 - accuracy: 0.9400 - f1_score: 0.9102 - precision: 0.9432 - recall: 0.9372 - val_loss: 0.1691 - val_accuracy: 0.9467 - val_f1_score: 0.9170 - val_precision: 0.9502 - val_recall: 0.9443 - lr: 0.0010
# Epoch 6/50
# 994/994 [==============================] - 700s 704ms/step - loss: 0.1724 - accuracy: 0.9418 - f1_score: 0.9135 - precision: 0.9448 - recall: 0.9394 - val_loss: 0.2134 - val_accuracy: 0.9361 - val_f1_score: 0.9066 - val_precision: 0.9391 - val_recall: 0.9339 - lr: 0.0010
# Epoch 7/50
# 994/994 [==============================] - 701s 705ms/step - loss: 0.1621 - accuracy: 0.9459 - f1_score: 0.9191 - precision: 0.9484 - recall: 0.9434 - val_loss: 0.1683 - val_accuracy: 0.9445 - val_f1_score: 0.9165 - val_precision: 0.9481 - val_recall: 0.9414 - lr: 0.0010
# Epoch 8/50
# 994/994 [==============================] - 703s 707ms/step - loss: 0.1548 - accuracy: 0.9481 - f1_score: 0.9226 - precision: 0.9505 - recall: 0.9457 - val_loss: 0.1593 - val_accuracy: 0.9484 - val_f1_score: 0.9228 - val_precision: 0.9522 - val_recall: 0.9439 - lr: 0.0010
# Epoch 9/50
# 994/994 [==============================] - 827s 832ms/step - loss: 0.1491 - accuracy: 0.9498 - f1_score: 0.9253 - precision: 0.9521 - recall: 0.9474 - val_loss: 0.1674 - val_accuracy: 0.9467 - val_f1_score: 0.9218 - val_precision: 0.9488 - val_recall: 0.9450 - lr: 0.0010
# Epoch 10/50
# 994/994 [==============================] - 1072s 1s/step - loss: 0.1454 - accuracy: 0.9512 - f1_score: 0.9272 - precision: 0.9532 - recall: 0.9490 - val_loss: 0.1929 - val_accuracy: 0.9417 - val_f1_score: 0.9068 - val_precision: 0.9432 - val_recall: 0.9406 - lr: 0.0010
# Epoch 11/50
# 994/994 [==============================] - 1733s 2s/step - loss: 0.1413 - accuracy: 0.9527 - f1_score: 0.9296 - precision: 0.9546 - recall: 0.9509 - val_loss: 0.1661 - val_accuracy: 0.9441 - val_f1_score: 0.9126 - val_precision: 0.9464 - val_recall: 0.9422 - lr: 0.0010
# Epoch 12/50
# 994/994 [==============================] - 714s 718ms/step - loss: 0.1388 - accuracy: 0.9529 - f1_score: 0.9300 - precision: 0.9548 - recall: 0.9513 - val_loss: 0.1579 - val_accuracy: 0.9497 - val_f1_score: 0.9247 - val_precision: 0.9517 - val_recall: 0.9476 - lr: 0.0010
# Epoch 13/50
# 994/994 [==============================] - 714s 718ms/step - loss: 0.1377 - accuracy: 0.9536 - f1_score: 0.9308 - precision: 0.9553 - recall: 0.9518 - val_loss: 0.1947 - val_accuracy: 0.9386 - val_f1_score: 0.8999 - val_precision: 0.9397 - val_recall: 0.9375 - lr: 0.0010
# Epoch 14/50
# 994/994 [==============================] - 717s 721ms/step - loss: 0.1329 - accuracy: 0.9553 - f1_score: 0.9331 - precision: 0.9569 - recall: 0.9536 - val_loss: 0.1682 - val_accuracy: 0.9458 - val_f1_score: 0.9174 - val_precision: 0.9472 - val_recall: 0.9445 - lr: 0.0010
# Epoch 15/50
# 994/994 [==============================] - 711s 716ms/step - loss: 0.1292 - accuracy: 0.9561 - f1_score: 0.9344 - precision: 0.9581 - recall: 0.9545 - val_loss: 0.1684 - val_accuracy: 0.9485 - val_f1_score: 0.9231 - val_precision: 0.9506 - val_recall: 0.9468 - lr: 0.0010
# Epoch 16/50
# 994/994 [==============================] - 713s 718ms/step - loss: 0.1273 - accuracy: 0.9559 - f1_score: 0.9339 - precision: 0.9575 - recall: 0.9545 - val_loss: 0.1757 - val_accuracy: 0.9438 - val_f1_score: 0.9133 - val_precision: 0.9461 - val_recall: 0.9408 - lr: 0.0010
# Epoch 17/50
# 994/994 [==============================] - 714s 718ms/step - loss: 0.1263 - accuracy: 0.9574 - f1_score: 0.9367 - precision: 0.9591 - recall: 0.9560 - val_loss: 0.1561 - val_accuracy: 0.9502 - val_f1_score: 0.9249 - val_precision: 0.9522 - val_recall: 0.9491 - lr: 0.0010
# Epoch 18/50
# 994/994 [==============================] - 712s 716ms/step - loss: 0.1254 - accuracy: 0.9580 - f1_score: 0.9374 - precision: 0.9595 - recall: 0.9568 - val_loss: 0.1737 - val_accuracy: 0.9461 - val_f1_score: 0.9154 - val_precision: 0.9483 - val_recall: 0.9445 - lr: 0.0010
# Epoch 19/50
# 994/994 [==============================] - 713s 717ms/step - loss: 0.1227 - accuracy: 0.9583 - f1_score: 0.9377 - precision: 0.9600 - recall: 0.9569 - val_loss: 0.1754 - val_accuracy: 0.9463 - val_f1_score: 0.9210 - val_precision: 0.9485 - val_recall: 0.9447 - lr: 0.0010
# Epoch 20/50
# 994/994 [==============================] - 715s 719ms/step - loss: 0.1207 - accuracy: 0.9589 - f1_score: 0.9386 - precision: 0.9605 - recall: 0.9575 - val_loss: 0.1778 - val_accuracy: 0.9443 - val_f1_score: 0.9146 - val_precision: 0.9465 - val_recall: 0.9425 - lr: 0.0010
# Epoch 21/50
# 994/994 [==============================] - 714s 719ms/step - loss: 0.1194 - accuracy: 0.9595 - f1_score: 0.9394 - precision: 0.9611 - recall: 0.9579 - val_loss: 0.1797 - val_accuracy: 0.9467 - val_f1_score: 0.9155 - val_precision: 0.9478 - val_recall: 0.9458 - lr: 0.0010
# Epoch 22/50
# 994/994 [==============================] - ETA: 0s - loss: 0.1179 - accuracy: 0.9596 - f1_score: 0.9398 - precision: 0.9611 - recall: 0.9584
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 994/994 [==============================] - 715s 719ms/step - loss: 0.1179 - accuracy: 0.9596 - f1_score: 0.9398 - precision: 0.9611 - recall: 0.9584 - val_loss: 0.1697 - val_accuracy: 0.9475 - val_f1_score: 0.9190 - val_precision: 0.9492 - val_recall: 0.9462 - lr: 0.0010
# Epoch 23/50
# 994/994 [==============================] - 714s 718ms/step - loss: 0.0899 - accuracy: 0.9692 - f1_score: 0.9538 - precision: 0.9699 - recall: 0.9684 - val_loss: 0.1538 - val_accuracy: 0.9537 - val_f1_score: 0.9282 - val_precision: 0.9548 - val_recall: 0.9533 - lr: 2.0000e-04
# Epoch 24/50
# 994/994 [==============================] - 715s 719ms/step - loss: 0.0841 - accuracy: 0.9703 - f1_score: 0.9553 - precision: 0.9710 - recall: 0.9697 - val_loss: 0.1472 - val_accuracy: 0.9563 - val_f1_score: 0.9334 - val_precision: 0.9581 - val_recall: 0.9556 - lr: 2.0000e-04
# Epoch 25/50
# 994/994 [==============================] - 717s 721ms/step - loss: 0.0822 - accuracy: 0.9708 - f1_score: 0.9560 - precision: 0.9715 - recall: 0.9704 - val_loss: 0.1445 - val_accuracy: 0.9546 - val_f1_score: 0.9303 - val_precision: 0.9559 - val_recall: 0.9539 - lr: 2.0000e-04
# Epoch 26/50
# 994/994 [==============================] - 729s 733ms/step - loss: 0.0791 - accuracy: 0.9719 - f1_score: 0.9576 - precision: 0.9725 - recall: 0.9713 - val_loss: 0.1442 - val_accuracy: 0.9530 - val_f1_score: 0.9274 - val_precision: 0.9540 - val_recall: 0.9522 - lr: 2.0000e-04
# Epoch 27/50
# 994/994 [==============================] - 710s 714ms/step - loss: 0.0778 - accuracy: 0.9722 - f1_score: 0.9581 - precision: 0.9726 - recall: 0.9716 - val_loss: 0.1496 - val_accuracy: 0.9557 - val_f1_score: 0.9325 - val_precision: 0.9566 - val_recall: 0.9551 - lr: 2.0000e-04
# Epoch 28/50
# 994/994 [==============================] - 712s 716ms/step - loss: 0.0759 - accuracy: 0.9729 - f1_score: 0.9591 - precision: 0.9733 - recall: 0.9723 - val_loss: 0.1482 - val_accuracy: 0.9548 - val_f1_score: 0.9313 - val_precision: 0.9554 - val_recall: 0.9544 - lr: 2.0000e-04
# Epoch 29/50
# 994/994 [==============================] - 719s 723ms/step - loss: 0.0776 - accuracy: 0.9720 - f1_score: 0.9577 - precision: 0.9726 - recall: 0.9714 - val_loss: 0.1460 - val_accuracy: 0.9553 - val_f1_score: 0.9315 - val_precision: 0.9564 - val_recall: 0.9543 - lr: 2.0000e-04
# Epoch 30/50
# 994/994 [==============================] - 712s 716ms/step - loss: 0.0728 - accuracy: 0.9732 - f1_score: 0.9594 - precision: 0.9737 - recall: 0.9728 - val_loss: 0.1469 - val_accuracy: 0.9545 - val_f1_score: 0.9317 - val_precision: 0.9554 - val_recall: 0.9538 - lr: 2.0000e-04
# Epoch 31/50
# 994/994 [==============================] - ETA: 0s - loss: 0.0724 - accuracy: 0.9734 - f1_score: 0.9598 - precision: 0.9739 - recall: 0.9730
# Epoch 31: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 994/994 [==============================] - 713s 717ms/step - loss: 0.0724 - accuracy: 0.9734 - f1_score: 0.9598 - precision: 0.9739 - recall: 0.9730 - val_loss: 0.1484 - val_accuracy: 0.9544 - val_f1_score: 0.9304 - val_precision: 0.9562 - val_recall: 0.9535 - lr: 2.0000e-04
# Epoch 32/50
# 994/994 [==============================] - 714s 718ms/step - loss: 0.0662 - accuracy: 0.9761 - f1_score: 0.9638 - precision: 0.9766 - recall: 0.9756 - val_loss: 0.1523 - val_accuracy: 0.9562 - val_f1_score: 0.9331 - val_precision: 0.9572 - val_recall: 0.9557 - lr: 4.0000e-05
# Epoch 33/50
# 994/994 [==============================] - 712s 716ms/step - loss: 0.0667 - accuracy: 0.9757 - f1_score: 0.9632 - precision: 0.9761 - recall: 0.9753 - val_loss: 0.1466 - val_accuracy: 0.9555 - val_f1_score: 0.9321 - val_precision: 0.9560 - val_recall: 0.9545 - lr: 4.0000e-05
# Epoch 34/50
# 994/994 [==============================] - 713s 717ms/step - loss: 0.0645 - accuracy: 0.9766 - f1_score: 0.9645 - precision: 0.9771 - recall: 0.9762 - val_loss: 0.1505 - val_accuracy: 0.9562 - val_f1_score: 0.9337 - val_precision: 0.9569 - val_recall: 0.9558 - lr: 4.0000e-05
# Epoch 35/50
# 994/994 [==============================] - 715s 720ms/step - loss: 0.0646 - accuracy: 0.9764 - f1_score: 0.9643 - precision: 0.9768 - recall: 0.9761 - val_loss: 0.1548 - val_accuracy: 0.9552 - val_f1_score: 0.9313 - val_precision: 0.9569 - val_recall: 0.9549 - lr: 4.0000e-05
# Epoch 36/50
# 994/994 [==============================] - ETA: 0s - loss: 0.0642 - accuracy: 0.9767 - f1_score: 0.9647 - precision: 0.9772 - recall: 0.9764
# Epoch 36: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 994/994 [==============================] - 712s 716ms/step - loss: 0.0642 - accuracy: 0.9767 - f1_score: 0.9647 - precision: 0.9772 - recall: 0.9764 - val_loss: 0.1484 - val_accuracy: 0.9549 - val_f1_score: 0.9306 - val_precision: 0.9559 - val_recall: 0.9541 - lr: 4.0000e-05
# Epoch 37/50
# 994/994 [==============================] - 715s 719ms/step - loss: 0.0631 - accuracy: 0.9769 - f1_score: 0.9649 - precision: 0.9774 - recall: 0.9765 - val_loss: 0.1585 - val_accuracy: 0.9556 - val_f1_score: 0.9320 - val_precision: 0.9564 - val_recall: 0.9551 - lr: 8.0000e-06
# Epoch 38/50
# 994/994 [==============================] - 715s 719ms/step - loss: 0.0611 - accuracy: 0.9772 - f1_score: 0.9653 - precision: 0.9775 - recall: 0.9768 - val_loss: 0.1570 - val_accuracy: 0.9545 - val_f1_score: 0.9308 - val_precision: 0.9553 - val_recall: 0.9540 - lr: 8.0000e-06
# Epoch 39/50
# 994/994 [==============================] - 713s 717ms/step - loss: 0.0631 - accuracy: 0.9767 - f1_score: 0.9647 - precision: 0.9770 - recall: 0.9763 - val_loss: 0.1535 - val_accuracy: 0.9548 - val_f1_score: 0.9304 - val_precision: 0.9555 - val_recall: 0.9541 - lr: 8.0000e-06
# Epoch 40/50
# 994/994 [==============================] - 715s 719ms/step - loss: 0.0636 - accuracy: 0.9771 - f1_score: 0.9652 - precision: 0.9774 - recall: 0.9767 - val_loss: 0.1540 - val_accuracy: 0.9548 - val_f1_score: 0.9314 - val_precision: 0.9555 - val_recall: 0.9542 - lr: 8.0000e-06
# Epoch 41/50
# 994/994 [==============================] - ETA: 0s - loss: 0.0617 - accuracy: 0.9772 - f1_score: 0.9655 - precision: 0.9776 - recall: 0.9769
# Epoch 41: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 994/994 [==============================] - 715s 719ms/step - loss: 0.0617 - accuracy: 0.9772 - f1_score: 0.9655 - precision: 0.9776 - recall: 0.9769 - val_loss: 0.1525 - val_accuracy: 0.9557 - val_f1_score: 0.9327 - val_precision: 0.9566 - val_recall: 0.9554 - lr: 8.0000e-06
# Epoch 42/50
# 994/994 [==============================] - 715s 719ms/step - loss: 0.0612 - accuracy: 0.9771 - f1_score: 0.9653 - precision: 0.9775 - recall: 0.9767 - val_loss: 0.1498 - val_accuracy: 0.9548 - val_f1_score: 0.9308 - val_precision: 0.9553 - val_recall: 0.9542 - lr: 1.6000e-06
# Epoch 43/50
# 994/994 [==============================] - 716s 720ms/step - loss: 0.0613 - accuracy: 0.9772 - f1_score: 0.9654 - precision: 0.9776 - recall: 0.9769 - val_loss: 0.1528 - val_accuracy: 0.9558 - val_f1_score: 0.9328 - val_precision: 0.9567 - val_recall: 0.9550 - lr: 1.6000e-06
# Epoch 44/50
# 994/994 [==============================] - 714s 718ms/step - loss: 0.0621 - accuracy: 0.9776 - f1_score: 0.9661 - precision: 0.9780 - recall: 0.9772 - val_loss: 0.1533 - val_accuracy: 0.9552 - val_f1_score: 0.9317 - val_precision: 0.9560 - val_recall: 0.9546 - lr: 1.6000e-06
# Epoch 45/50
# 994/994 [==============================] - 714s 718ms/step - loss: 0.0616 - accuracy: 0.9779 - f1_score: 0.9666 - precision: 0.9784 - recall: 0.9777 - val_loss: 0.1534 - val_accuracy: 0.9566 - val_f1_score: 0.9334 - val_precision: 0.9573 - val_recall: 0.9561 - lr: 1.6000e-06
# Epoch 46/50
# 994/994 [==============================] - ETA: 0s - loss: 0.0615 - accuracy: 0.9771 - f1_score: 0.9654 - precision: 0.9775 - recall: 0.9767
# Epoch 46: ReduceLROnPlateau reducing learning rate to 1e-06.
# 994/994 [==============================] - 715s 719ms/step - loss: 0.0615 - accuracy: 0.9771 - f1_score: 0.9654 - precision: 0.9775 - recall: 0.9767 - val_loss: 0.1516 - val_accuracy: 0.9548 - val_f1_score: 0.9305 - val_precision: 0.9554 - val_recall: 0.9545 - lr: 1.6000e-06
# Epoch 47/50
# 994/994 [==============================] - 709s 713ms/step - loss: 0.0616 - accuracy: 0.9771 - f1_score: 0.9652 - precision: 0.9775 - recall: 0.9767 - val_loss: 0.1551 - val_accuracy: 0.9551 - val_f1_score: 0.9314 - val_precision: 0.9559 - val_recall: 0.9547 - lr: 1.0000e-06
# Epoch 48/50
# 994/994 [==============================] - 708s 712ms/step - loss: 0.0617 - accuracy: 0.9770 - f1_score: 0.9652 - precision: 0.9773 - recall: 0.9767 - val_loss: 0.1609 - val_accuracy: 0.9555 - val_f1_score: 0.9319 - val_precision: 0.9563 - val_recall: 0.9551 - lr: 1.0000e-06
# Epoch 49/50
# 994/994 [==============================] - 712s 716ms/step - loss: 0.0608 - accuracy: 0.9774 - f1_score: 0.9657 - precision: 0.9778 - recall: 0.9770 - val_loss: 0.1532 - val_accuracy: 0.9543 - val_f1_score: 0.9298 - val_precision: 0.9550 - val_recall: 0.9534 - lr: 1.0000e-06
# Epoch 50/50
# 994/994 [==============================] - 713s 717ms/step - loss: 0.0611 - accuracy: 0.9775 - f1_score: 0.9658 - precision: 0.9778 - recall: 0.9771 - val_loss: 0.1496 - val_accuracy: 0.9561 - val_f1_score: 0.9323 - val_precision: 0.9568 - val_recall: 0.9555 - lr: 1.0000e-06

# %%
best_epoch = np.argmax(history.history['val_accuracy']) + 1  # Adding 1 as epochs start from 1, not 0

# Find the value of the maximum validation accuracy
best_accuracy = np.max(history.history['val_accuracy'])

print(f"The best validation accuracy was {best_accuracy:.4f} at epoch {best_epoch}")
# Out:
# The best validation accuracy was 0.9566 at epoch 45

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 3))
ax = ax.ravel()

for i, met in enumerate(['accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
# Evaluate the model on test set
test_loss, test_accuracy, test_f1, test_precision, test_recall = model.evaluate(test_generator)

# Print evaluation metrics
print(f'Test Loss: {test_loss}')
print(f'Test Accuracy: {test_accuracy}')
print(f'Test f1 score: {test_f1}')
print(f'Test Precision: {test_precision}')
print(f'Test Recall: {test_recall}')
# Out:
# 63/63 [==============================] - 44s 713ms/step - loss: 0.1852 - accuracy: 0.9413 - f1_score: 0.9411 - precision: 0.9417 - recall: 0.9408
# Test Loss: 0.1852325201034546
# Test Accuracy: 0.9412500262260437
# Test f1 score: [0.9429952  0.9507006  0.92548203 0.94529754]
# Test Precision: 0.9416916966438293
# Test Recall: 0.940750002861023

# %%
# Generate predictions for the test set
predictions = model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)

# Get true labels for the test set
true_labels = test_generator.classes

# Ensure the true labels and predicted labels have the same length
if predicted_classes.shape[0] != true_labels.shape[0]:
    n_seq = true_labels.shape[0] // predicted_classes.shape[0]
    true_labels = np.repeat(true_labels, n_seq)

# Generate a classification report
report = classification_report(true_labels, predicted_classes, target_names=test_generator.class_indices.keys())
print(report)
# Out:
# 63/63 [==============================] - 10s 152ms/step
#               precision    recall  f1-score   support
#
#          CNV       0.91      0.98      0.94      1000
#          DME       0.99      0.92      0.95      1000
#       DRUSEN       0.97      0.89      0.93      1000
#       Normal       0.91      0.98      0.95      1000
#
#     accuracy                           0.94      4000
#    macro avg       0.94      0.94      0.94      4000
# weighted avg       0.94      0.94      0.94      4000

# %%
# import numpy as np
# from sklearn.metrics import confusion_matrix
# import seaborn as sns
# import matplotlib.pyplot as plt

# Get the true labels
true_labels = test_generator.classes

# Predict the labels using the model
predictions = model.predict(test_generator)
predicted_labels = np.argmax(predictions, axis=1)

# Compute the confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)

# Plot the confusion matrix
plt.figure(figsize=(10,7))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 63/63 [==============================] - 10s 151ms/step

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# import math

epochs = len(history.history['loss'])
batch_size = 96
train_data_size = 63588

steps_per_epoch = math.ceil(train_data_size / batch_size)
total_steps = np.arange(steps_per_epoch, epochs * steps_per_epoch + 1, steps_per_epoch)

fig, ax = plt.subplots(1, 2, figsize=(10, 3))
ax = ax.ravel()

for i, met in enumerate(['accuracy', 'loss']):
    ax[i].plot(total_steps, history.history[met], '-o')
    ax[i].plot(total_steps, history.history['val_' + met], '-o')
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('steps')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])
    ax[i].set_xticks(total_steps)

# %%
model.save('C:/Users/user/projects/t81_558_deep_learning/Abletion test/Layer selection/saved models/10_layer_Abletion_v1.h5')

# %%
from sklearn.metrics import f1_score

# Get true labels for the test set
true_labels = test_generator.classes

# Generate predictions for the test set
predictions = model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)

# Compute the F1 score for each class
f1_per_class = f1_score(true_labels, predicted_classes, average=None)

# Compute the average F1 score across all classes
average_f1 = sum(f1_per_class) / len(f1_per_class)

# Print the F1 score for each class
for i, f1_class in enumerate(f1_per_class):
    print(f'F1 Score for Class {i}: {f1_class}')

# Print the average F1 score
print(f'Average F1 Score: {average_f1}')
# Out:
# 63/63 [==============================] - 9s 149ms/step
# F1 Score for Class 0: 0.9429951690821257
# F1 Score for Class 1: 0.9507005708354956
# F1 Score for Class 2: 0.9254820218863992
# F1 Score for Class 3: 0.9452975047984645
# Average F1 Score: 0.9411188166506212

# %% [markdown]
# # GRADCAM

# %%
def make_gradcam_heatmap(img_array, model, last_conv_layer_name, classifier_layer_names, pred_index=None):
    # First, we create a model that maps the input image to the activations
    # of the last conv layer as well as the output predictions
    grad_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )

    # Then, we compute the gradient of the top predicted class for our input image
    # with respect to the activations of the last conv layer
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]

    # This is the gradient of the output neuron (top predicted or chosen)
    # with regard to the output feature map of the last conv layer
    grads = tape.gradient(class_channel, last_conv_layer_output)

    # This is a vector where each entry is the mean intensity of the gradient
    # over a specific feature map channel
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

# %%
# Load your image
# Specify the path to an image in your test set
img_path = 'D:/Thesis dataset/FINAL DATASET/4k_UNIQUE_Test/test/CNV/CNV-163081-230.JPEG'
 # Replace with your local image path
img = load_img(img_path, color_mode='grayscale', target_size=(224, 224))  # Set color_mode to 'grayscale'
img = img_to_array(img)

img = np.expand_dims(img, axis=0)
img = np.repeat(img, 3, axis=-1)
# img = preprocess_input(img)
img /= 255.0
# Display the image
plt.imshow(np.squeeze(img))  # Divide by 255.0 if img_rgb is scaled from 0 to 255
plt.axis('off')  # Hide the axis
plt.show()




# Predict the class (index)
preds = model.predict(img)
pred_index = np.argmax(preds[0])

# Generate class activation heatmap
last_conv_layer_name = 'Conv_4-2'  # Change to match the name of the last conv layer in your model
classifier_layer_names = []  # You may not need this for Sequential models
heatmap = make_gradcam_heatmap(img, model, last_conv_layer_name, classifier_layer_names, pred_index)

# Display heatmap
plt.matshow(heatmap)
plt.show()

# We load the original image
# We load the original grayscale image
original_img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)  # Load as grayscale

# Resize the heatmap to match the original image size
heatmap = cv2.resize(heatmap, (original_img.shape[1], original_img.shape[0]))
heatmap = np.uint8(255 * heatmap)
heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)

# Superimpose the heatmap on grayscale image
superimposed_img = cv2.cvtColor(original_img, cv2.COLOR_GRAY2BGR)  # Convert grayscale to BGR format
superimposed_img = heatmap * 0.4 + superimposed_img
superimposed_img = superimposed_img.astype('uint8')

# Superimpose the heatmap on original image
# superimposed_img = heatmap * 0.4 + original_img

# Save the image to disk
save_path = 'D:/Thesis dataset/FINAL DATASET/GRADCAM SAVED IMAGES/Ablation/10 layer/CNV-163081-230.JPEG'  # Replace with your save path
cv2.imwrite(save_path, superimposed_img)

# Display Image
plt.imshow(cv2.cvtColor(superimposed_img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 413ms/step

# %%
# Load your image

img_path ='D:/Thesis dataset/FINAL DATASET/4k_UNIQUE_Test/test/DME/DME-30521-17.jpeg'  # Replace with your local image path
img = load_img(img_path, color_mode='grayscale', target_size=(224, 224))  # Set color_mode to 'grayscale'
img = img_to_array(img)

img = np.expand_dims(img, axis=0)
img = np.repeat(img, 3, axis=-1)
# img = preprocess_input(img)
img /= 255.0
# Display the image
plt.imshow(np.squeeze(img))  # Divide by 255.0 if img_rgb is scaled from 0 to 255
plt.axis('off')  # Hide the axis
plt.show()

# Predict the class (index)
preds = model.predict(img)
pred_index = np.argmax(preds[0])

# Generate class activation heatmap
last_conv_layer_name = 'Conv_4-2'  # Change to match the name of the last conv layer in your model
classifier_layer_names = []  # You may not need this for Sequential models
heatmap = make_gradcam_heatmap(img, model, last_conv_layer_name, classifier_layer_names, pred_index)

# Display heatmap
plt.matshow(heatmap)
plt.show()

# We load the original image
# We load the original grayscale image
original_img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)  # Load as grayscale

# Resize the heatmap to match the original image size
heatmap = cv2.resize(heatmap, (original_img.shape[1], original_img.shape[0]))
heatmap = np.uint8(255 * heatmap)
heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)

# Superimpose the heatmap on grayscale image
superimposed_img = cv2.cvtColor(original_img, cv2.COLOR_GRAY2BGR)  # Convert grayscale to BGR format
superimposed_img = heatmap * 0.4 + superimposed_img
superimposed_img = superimposed_img.astype('uint8')

# Superimpose the heatmap on original image
# superimposed_img = heatmap * 0.4 + original_img

# Save the image to disk
save_path = 'D:/Thesis dataset/FINAL DATASET/GRADCAM SAVED IMAGES/Ablation/10 layer/DME-30521-17.jpeg'  # Replace with your save path
cv2.imwrite(save_path, superimposed_img)

# Display Image
plt.imshow(cv2.cvtColor(superimposed_img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 18ms/step

# %%
# Load your image

img_path ='D:/Thesis dataset/FINAL DATASET/4k_UNIQUE_Test/test/DRUSEN/DRUSEN-95633-23.jpeg'  # Replace with your local image path
img = load_img(img_path, color_mode='grayscale', target_size=(224, 224))  # Set color_mode to 'grayscale'
img = img_to_array(img)

img = np.expand_dims(img, axis=0)
img = np.repeat(img, 3, axis=-1)
# img = preprocess_input(img)
img /= 255.0
# Display the image
plt.imshow(np.squeeze(img))  # Divide by 255.0 if img_rgb is scaled from 0 to 255
plt.axis('off')  # Hide the axis
plt.show()

# Predict the class (index)
preds = model.predict(img)
pred_index = np.argmax(preds[0])

# Generate class activation heatmap
last_conv_layer_name = 'Conv_4-2'  # Change to match the name of the last conv layer in your model
classifier_layer_names = []  # You may not need this for Sequential models
heatmap = make_gradcam_heatmap(img, model, last_conv_layer_name, classifier_layer_names, pred_index)

# Display heatmap
plt.matshow(heatmap)
plt.show()

# We load the original image
# We load the original grayscale image
original_img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)  # Load as grayscale

# Resize the heatmap to match the original image size
heatmap = cv2.resize(heatmap, (original_img.shape[1], original_img.shape[0]))
heatmap = np.uint8(255 * heatmap)
heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)

# Superimpose the heatmap on grayscale image
superimposed_img = cv2.cvtColor(original_img, cv2.COLOR_GRAY2BGR)  # Convert grayscale to BGR format
superimposed_img = heatmap * 0.4 + superimposed_img
superimposed_img = superimposed_img.astype('uint8')

# Superimpose the heatmap on original image
# superimposed_img = heatmap * 0.4 + original_img

# Save the image to disk
save_path ='D:/Thesis dataset/FINAL DATASET/GRADCAM SAVED IMAGES/Ablation/10 layer/DRUSEN-95633-23.jpeg'  # Replace with your save path
cv2.imwrite(save_path, superimposed_img)

# Display Image
plt.imshow(cv2.cvtColor(superimposed_img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 16ms/step

# %%
# Load your image
img_path = 'D:/Thesis dataset/FINAL DATASET/4k_UNIQUE_Test/test/NORMAL/NORMAL-33637-1.jpeg' # Replace with your local image path
img = load_img(img_path, color_mode='grayscale', target_size=(224, 224))  # Set color_mode to 'grayscale'
img = img_to_array(img)

img = np.expand_dims(img, axis=0)
img = np.repeat(img, 3, axis=-1)
# img = preprocess_input(img)
img /= 255.0
# Display the image
plt.imshow(np.squeeze(img))  # Divide by 255.0 if img_rgb is scaled from 0 to 255
plt.axis('off')  # Hide the axis
plt.show()

# Predict the class (index)
preds = model.predict(img)
pred_index = np.argmax(preds[0])

# Generate class activation heatmap
last_conv_layer_name = 'Conv_4-2'  # Change to match the name of the last conv layer in your model
classifier_layer_names = []  # You may not need this for Sequential models
heatmap = make_gradcam_heatmap(img, model, last_conv_layer_name, classifier_layer_names, pred_index)

# Display heatmap
plt.matshow(heatmap)
plt.show()

# We load the original image
# We load the original grayscale image
original_img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)  # Load as grayscale

# Resize the heatmap to match the original image size
heatmap = cv2.resize(heatmap, (original_img.shape[1], original_img.shape[0]))
heatmap = np.uint8(255 * heatmap)
heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)

# Superimpose the heatmap on grayscale image
superimposed_img = cv2.cvtColor(original_img, cv2.COLOR_GRAY2BGR)  # Convert grayscale to BGR format
superimposed_img = heatmap * 0.4 + superimposed_img
superimposed_img = superimposed_img.astype('uint8')

# Superimpose the heatmap on original image
# superimposed_img = heatmap * 0.4 + original_img

# Save the image to disk
save_path = 'D:/Thesis dataset/FINAL DATASET/GRADCAM SAVED IMAGES/Ablation/10 layer/NORMAL-33637-1.jpeg'  # Replace with your save path
cv2.imwrite(save_path, superimposed_img)

# Display Image
plt.imshow(cv2.cvtColor(superimposed_img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 20ms/step

# %% [markdown]
# ## (750 + 250)

# %%
input_dir = "D:/Thesis dataset/vgg16/visualization/"
train_dir = input_dir +"train/"
test_dir = input_dir +"test(750+250)/"


test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(224, 224),
        batch_size=64,
        class_mode='categorical',
        shuffle = False
)


test_loss, test_accuracy, test_f1, test_precision, test_recall = model.evaluate(test_generator)

# Print evaluation metrics
print(f'Test Loss: {test_loss}')
print(f'Test Accuracy: {test_accuracy}')
print(f'Test f1 score: {test_f1}')
print(f'Test Precision: {test_precision}')
print(f'Test Recall: {test_recall}')


# Generate predictions for the test set
predictions = model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)

# Get true labels for the test set
true_labels = test_generator.classes

# Ensure the true labels and predicted labels have the same length
if predicted_classes.shape[0] != true_labels.shape[0]:
    n_seq = true_labels.shape[0] // predicted_classes.shape[0]
    true_labels = np.repeat(true_labels, n_seq)

# Generate a classification report
report = classification_report(true_labels, predicted_classes, target_names=test_generator.class_indices.keys())
print(report)


# Get the true labels
true_labels = test_generator.classes

# Predict the labels using the model
predictions = model.predict(test_generator)
predicted_labels = np.argmax(predictions, axis=1)

# Compute the confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)

# Plot the confusion matrix
plt.figure(figsize=(10,7))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Found 4000 images belonging to 4 classes.
# 63/63 [==============================] - 56s 899ms/step - loss: 0.0954 - accuracy: 0.9670 - f1_score: 0.9669 - precision: 0.9670 - recall: 0.9668
# Test Loss: 0.09543328732252121
# Test Accuracy: 0.9670000076293945
# Test f1 score: [0.96733296 0.9740722  0.956163   0.97014195]
# Test Precision: 0.9669917225837708
# Test Recall: 0.9667500257492065
# 63/63 [==============================] - 9s 148ms/step
#               precision    recall  f1-score   support
#
#          CNV       0.94      0.99      0.97      1000
#          DME       0.99      0.96      0.97      1000
#       DRUSEN       0.99      0.93      0.96      1000
#       NORMAL       0.95      0.99      0.97      1000
#
#     accuracy                           0.97      4000
#    macro avg       0.97      0.97      0.97      4000
# weighted avg       0.97      0.97      0.97      4000
#
# 63/63 [==============================] - 10s 155ms/step

# %%
from sklearn.metrics import f1_score

# Get true labels for the test set
true_labels = test_generator.classes

# Generate predictions for the test set
predictions = model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)

# Compute the F1 score for each class
f1_per_class = f1_score(true_labels, predicted_classes, average=None)

# Compute the average F1 score across all classes
average_f1 = sum(f1_per_class) / len(f1_per_class)

# Print the F1 score for each class
for i, f1_class in enumerate(f1_per_class):
    print(f'F1 Score for Class {i}: {f1_class}')

# Print the average F1 score
print(f'Average F1 Score: {average_f1}')
# Out:
# 63/63 [==============================] - 9s 146ms/step
# F1 Score for Class 0: 0.9673330082886397
# F1 Score for Class 1: 0.9740721911540416
# F1 Score for Class 2: 0.9561629706034038
# F1 Score for Class 3: 0.9701419481155165
# Average F1 Score: 0.9669275295404005
