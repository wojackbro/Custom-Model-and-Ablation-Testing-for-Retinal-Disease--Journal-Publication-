# %%
# !pip install pandas

# %%
# !pip install matplotlib

# %%
# !pip install seaborn

# %%
# !pip install opencv-python

# %%
# !pip install scikit-learn

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import keras
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
import tensorflow as tf
import matplotlib.cm as cm
import cv2
import math

# %%
from keras.applications.vgg16 import VGG16
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Input
from keras.models import Model
from keras.layers import Dense
from keras.optimizers import Adam
from sklearn import model_selection
from sklearn.model_selection import train_test_split, KFold, cross_val_score, StratifiedKFold, GridSearchCV
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, make_scorer, accuracy_score, classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.imagenet_utils import preprocess_input
from tensorflow.keras import layers, models
from tensorflow.keras.metrics import Precision, Recall
from keras.callbacks import ReduceLROnPlateau
# from sklearn.metrics import classification_report

# %%
input_dir = "D:/Thesis dataset/FINAL DATASET/4k_UNIQUE_Test/"
train_dir = input_dir +"train/"
test_dir = input_dir +"test/"

# %%
# Data Augmentation
train_datagen = ImageDataGenerator(
      rescale=1./255,
       rotation_range=10,
       width_shift_range=0.1,
       height_shift_range=0.1,
       shear_range=0.1,
       zoom_range=0.1,
       #horizontal_flip=True,
       fill_mode='nearest',
      validation_split=0.2
)

test_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(224, 224),
        batch_size=64,
        class_mode='categorical',
        subset='training'

)
test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(224, 224),
        batch_size=64,
        class_mode='categorical',
        shuffle = False
)
validation_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(224, 224),
        batch_size=64,
        class_mode='categorical',
        subset='validation'
)
#class_weights = {0: 1.0, 1: 3.43, 2: 4.61, 3: 1.41}
# Out:
# Found 63588 images belonging to 4 classes.
# Found 4000 images belonging to 4 classes.
# Found 15896 images belonging to 4 classes.

# %%
model = Sequential([
    # Input layer
    tf.keras.layers.InputLayer(input_shape=(224, 224, 3)),

    # Conv block 1
    Conv2D(16, kernel_size=(3,3), padding='same', activation='relu', name="Conv_1-1"),
    MaxPooling2D(pool_size=(2,2), strides=2),

    # Conv block 2
    Conv2D(16, kernel_size=(3,3), padding='same', activation='relu', name="Conv_2-1"),
    MaxPooling2D(pool_size=(2,2), strides=2),

    # Conv block 3
    Conv2D(32, kernel_size=(3,3), padding='same', activation='relu', name="Conv_3-1"),
    Conv2D(48, kernel_size=(3,3), padding='same', activation='relu', name="Conv_3-2"),
    MaxPooling2D(pool_size=(2,2), strides=2),

    # Conv block 4
    Conv2D(48, kernel_size=(3,3), padding='same', activation='relu', name="Conv_4-1"),
    Conv2D(64, kernel_size=(3,3), padding='same', activation='relu', name="Conv_4-2"),
    MaxPooling2D(pool_size=(2,2), strides=2),

    # Flatten
    Flatten(),

    # Fully connected layers
    Dense(512, activation='relu'),
    Dense(512, activation='relu'),
    #Dense(4, activation='relu'),
    #Dropout(0.4),

    # Output layer
    Dense(4, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Conv_1-1 (Conv2D)           (None, 224, 224, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 16)     0
#  )
#
#  Conv_2-1 (Conv2D)           (None, 112, 112, 16)      2320
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 16)       0
#  2D)
#
#  Conv_3-1 (Conv2D)           (None, 56, 56, 32)        4640
#
#  Conv_3-2 (Conv2D)           (None, 56, 56, 48)        13872
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 48)       0
#  2D)
#
#  Conv_4-1 (Conv2D)           (None, 28, 28, 48)        20784
#
#  Conv_4-2 (Conv2D)           (None, 28, 28, 64)        27712
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dense (Dense)               (None, 512)               6423040
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dense_2 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 6,757,524
# Trainable params: 6,757,524
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow_addons as tfa
lr = 0.001
model.compile(
        loss='categorical_crossentropy',
        optimizer=Adam(lr=lr),
        metrics=['accuracy', tfa.metrics.F1Score(num_classes=4), Precision(), Recall()]
    )

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6, verbose=1)

# %%
history = model.fit_generator(
    train_generator,
#     steps_per_epoch = 50,
    epochs = 50,
    validation_data = validation_generator,
    #validation_steps = 50
    #class_weight = class_weights
    callbacks = [reduce_lr]
)
# Out:
# Epoch 1/50
# 994/994 [==============================] - 2161s 2s/step - loss: 0.6754 - accuracy: 0.7420 - f1_score: 0.5704 - precision: 0.8261 - recall: 0.6538 - val_loss: 0.4159 - val_accuracy: 0.8547 - val_f1_score: 0.7481 - val_precision: 0.8686 - val_recall: 0.8394 - lr: 0.0010
# Epoch 2/50
# 994/994 [==============================] - 704s 708ms/step - loss: 0.3270 - accuracy: 0.8872 - f1_score: 0.8272 - precision: 0.8976 - recall: 0.8761 - val_loss: 0.2953 - val_accuracy: 0.9017 - val_f1_score: 0.8415 - val_precision: 0.9104 - val_recall: 0.8951 - lr: 0.0010
# Epoch 3/50
# 994/994 [==============================] - 707s 711ms/step - loss: 0.2517 - accuracy: 0.9144 - f1_score: 0.8713 - precision: 0.9204 - recall: 0.9088 - val_loss: 0.2456 - val_accuracy: 0.9177 - val_f1_score: 0.8624 - val_precision: 0.9245 - val_recall: 0.9119 - lr: 0.0010
# Epoch 4/50
# 994/994 [==============================] - 702s 706ms/step - loss: 0.2183 - accuracy: 0.9263 - f1_score: 0.8892 - precision: 0.9308 - recall: 0.9222 - val_loss: 0.2121 - val_accuracy: 0.9260 - val_f1_score: 0.8880 - val_precision: 0.9315 - val_recall: 0.9219 - lr: 0.0010
# Epoch 5/50
# 994/994 [==============================] - 704s 708ms/step - loss: 0.2012 - accuracy: 0.9327 - f1_score: 0.8987 - precision: 0.9364 - recall: 0.9289 - val_loss: 0.1823 - val_accuracy: 0.9394 - val_f1_score: 0.9064 - val_precision: 0.9441 - val_recall: 0.9364 - lr: 0.0010
# Epoch 6/50
# 994/994 [==============================] - 704s 708ms/step - loss: 0.1846 - accuracy: 0.9378 - f1_score: 0.9069 - precision: 0.9408 - recall: 0.9350 - val_loss: 0.2152 - val_accuracy: 0.9301 - val_f1_score: 0.8962 - val_precision: 0.9337 - val_recall: 0.9273 - lr: 0.0010
# Epoch 7/50
# 994/994 [==============================] - 704s 708ms/step - loss: 0.1769 - accuracy: 0.9407 - f1_score: 0.9113 - precision: 0.9434 - recall: 0.9380 - val_loss: 0.1967 - val_accuracy: 0.9344 - val_f1_score: 0.8974 - val_precision: 0.9383 - val_recall: 0.9310 - lr: 0.0010
# Epoch 8/50
# 994/994 [==============================] - 701s 706ms/step - loss: 0.1672 - accuracy: 0.9432 - f1_score: 0.9151 - precision: 0.9459 - recall: 0.9404 - val_loss: 0.1872 - val_accuracy: 0.9385 - val_f1_score: 0.9061 - val_precision: 0.9411 - val_recall: 0.9363 - lr: 0.0010
# Epoch 9/50
# 994/994 [==============================] - 704s 708ms/step - loss: 0.1605 - accuracy: 0.9449 - f1_score: 0.9173 - precision: 0.9472 - recall: 0.9424 - val_loss: 0.1904 - val_accuracy: 0.9397 - val_f1_score: 0.9054 - val_precision: 0.9432 - val_recall: 0.9370 - lr: 0.0010
# Epoch 10/50
# 994/994 [==============================] - 703s 707ms/step - loss: 0.1551 - accuracy: 0.9475 - f1_score: 0.9209 - precision: 0.9498 - recall: 0.9453 - val_loss: 0.1663 - val_accuracy: 0.9443 - val_f1_score: 0.9147 - val_precision: 0.9471 - val_recall: 0.9411 - lr: 0.0010
# Epoch 11/50
# 994/994 [==============================] - 705s 710ms/step - loss: 0.1513 - accuracy: 0.9488 - f1_score: 0.9229 - precision: 0.9509 - recall: 0.9467 - val_loss: 0.1866 - val_accuracy: 0.9383 - val_f1_score: 0.9101 - val_precision: 0.9426 - val_recall: 0.9352 - lr: 0.0010
# Epoch 12/50
# 994/994 [==============================] - 705s 709ms/step - loss: 0.1479 - accuracy: 0.9507 - f1_score: 0.9261 - precision: 0.9529 - recall: 0.9486 - val_loss: 0.1819 - val_accuracy: 0.9429 - val_f1_score: 0.9130 - val_precision: 0.9462 - val_recall: 0.9409 - lr: 0.0010
# Epoch 13/50
# 994/994 [==============================] - 703s 707ms/step - loss: 0.1440 - accuracy: 0.9498 - f1_score: 0.9249 - precision: 0.9519 - recall: 0.9479 - val_loss: 0.2027 - val_accuracy: 0.9358 - val_f1_score: 0.8984 - val_precision: 0.9399 - val_recall: 0.9324 - lr: 0.0010
# Epoch 14/50
# 994/994 [==============================] - 705s 709ms/step - loss: 0.1411 - accuracy: 0.9517 - f1_score: 0.9277 - precision: 0.9536 - recall: 0.9497 - val_loss: 0.1653 - val_accuracy: 0.9464 - val_f1_score: 0.9183 - val_precision: 0.9493 - val_recall: 0.9446 - lr: 0.0010
# Epoch 15/50
# 994/994 [==============================] - 702s 707ms/step - loss: 0.1339 - accuracy: 0.9543 - f1_score: 0.9316 - precision: 0.9565 - recall: 0.9524 - val_loss: 0.1867 - val_accuracy: 0.9399 - val_f1_score: 0.9092 - val_precision: 0.9426 - val_recall: 0.9377 - lr: 0.0010
# Epoch 16/50
# 994/994 [==============================] - 703s 707ms/step - loss: 0.1341 - accuracy: 0.9538 - f1_score: 0.9304 - precision: 0.9554 - recall: 0.9524 - val_loss: 0.1798 - val_accuracy: 0.9450 - val_f1_score: 0.9159 - val_precision: 0.9471 - val_recall: 0.9433 - lr: 0.0010
# Epoch 17/50
# 994/994 [==============================] - 707s 711ms/step - loss: 0.1333 - accuracy: 0.9551 - f1_score: 0.9324 - precision: 0.9574 - recall: 0.9534 - val_loss: 0.1742 - val_accuracy: 0.9434 - val_f1_score: 0.9121 - val_precision: 0.9456 - val_recall: 0.9419 - lr: 0.0010
# Epoch 18/50
# 994/994 [==============================] - 703s 707ms/step - loss: 0.1287 - accuracy: 0.9552 - f1_score: 0.9329 - precision: 0.9572 - recall: 0.9538 - val_loss: 0.1942 - val_accuracy: 0.9386 - val_f1_score: 0.9069 - val_precision: 0.9408 - val_recall: 0.9368 - lr: 0.0010
# Epoch 19/50
# 994/994 [==============================] - ETA: 0s - loss: 0.1276 - accuracy: 0.9569 - f1_score: 0.9349 - precision: 0.9586 - recall: 0.9551
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 994/994 [==============================] - 701s 706ms/step - loss: 0.1276 - accuracy: 0.9569 - f1_score: 0.9349 - precision: 0.9586 - recall: 0.9551 - val_loss: 0.1660 - val_accuracy: 0.9482 - val_f1_score: 0.9218 - val_precision: 0.9504 - val_recall: 0.9463 - lr: 0.0010
# Epoch 20/50
# 994/994 [==============================] - 704s 708ms/step - loss: 0.1028 - accuracy: 0.9642 - f1_score: 0.9458 - precision: 0.9657 - recall: 0.9630 - val_loss: 0.1725 - val_accuracy: 0.9467 - val_f1_score: 0.9160 - val_precision: 0.9489 - val_recall: 0.9455 - lr: 2.0000e-04
# Epoch 21/50
# 994/994 [==============================] - 703s 708ms/step - loss: 0.0968 - accuracy: 0.9659 - f1_score: 0.9484 - precision: 0.9672 - recall: 0.9648 - val_loss: 0.1583 - val_accuracy: 0.9490 - val_f1_score: 0.9211 - val_precision: 0.9509 - val_recall: 0.9480 - lr: 2.0000e-04
# Epoch 22/50
# 994/994 [==============================] - 705s 709ms/step - loss: 0.0943 - accuracy: 0.9666 - f1_score: 0.9494 - precision: 0.9675 - recall: 0.9655 - val_loss: 0.1584 - val_accuracy: 0.9494 - val_f1_score: 0.9220 - val_precision: 0.9514 - val_recall: 0.9480 - lr: 2.0000e-04
# Epoch 23/50
# 994/994 [==============================] - 705s 709ms/step - loss: 0.0929 - accuracy: 0.9668 - f1_score: 0.9498 - precision: 0.9679 - recall: 0.9661 - val_loss: 0.1563 - val_accuracy: 0.9496 - val_f1_score: 0.9227 - val_precision: 0.9520 - val_recall: 0.9485 - lr: 2.0000e-04
# Epoch 24/50
# 994/994 [==============================] - 932s 938ms/step - loss: 0.0910 - accuracy: 0.9682 - f1_score: 0.9517 - precision: 0.9692 - recall: 0.9675 - val_loss: 0.1628 - val_accuracy: 0.9516 - val_f1_score: 0.9256 - val_precision: 0.9526 - val_recall: 0.9501 - lr: 2.0000e-04
# Epoch 25/50
# 994/994 [==============================] - 1370s 1s/step - loss: 0.0896 - accuracy: 0.9685 - f1_score: 0.9522 - precision: 0.9693 - recall: 0.9677 - val_loss: 0.1764 - val_accuracy: 0.9489 - val_f1_score: 0.9225 - val_precision: 0.9507 - val_recall: 0.9478 - lr: 2.0000e-04
# Epoch 26/50
# 994/994 [==============================] - 712s 717ms/step - loss: 0.0860 - accuracy: 0.9701 - f1_score: 0.9547 - precision: 0.9707 - recall: 0.9693 - val_loss: 0.1531 - val_accuracy: 0.9514 - val_f1_score: 0.9257 - val_precision: 0.9529 - val_recall: 0.9502 - lr: 2.0000e-04
# Epoch 27/50
# 994/994 [==============================] - 705s 709ms/step - loss: 0.0864 - accuracy: 0.9689 - f1_score: 0.9529 - precision: 0.9698 - recall: 0.9682 - val_loss: 0.1703 - val_accuracy: 0.9472 - val_f1_score: 0.9190 - val_precision: 0.9485 - val_recall: 0.9463 - lr: 2.0000e-04
# Epoch 28/50
# 994/994 [==============================] - 707s 711ms/step - loss: 0.0841 - accuracy: 0.9706 - f1_score: 0.9553 - precision: 0.9713 - recall: 0.9700 - val_loss: 0.1654 - val_accuracy: 0.9502 - val_f1_score: 0.9235 - val_precision: 0.9515 - val_recall: 0.9487 - lr: 2.0000e-04
# Epoch 29/50
# 994/994 [==============================] - 705s 709ms/step - loss: 0.0824 - accuracy: 0.9704 - f1_score: 0.9551 - precision: 0.9710 - recall: 0.9697 - val_loss: 0.1635 - val_accuracy: 0.9500 - val_f1_score: 0.9244 - val_precision: 0.9513 - val_recall: 0.9488 - lr: 2.0000e-04
# Epoch 30/50
# 994/994 [==============================] - 702s 706ms/step - loss: 0.0837 - accuracy: 0.9703 - f1_score: 0.9548 - precision: 0.9711 - recall: 0.9697 - val_loss: 0.1684 - val_accuracy: 0.9515 - val_f1_score: 0.9263 - val_precision: 0.9526 - val_recall: 0.9504 - lr: 2.0000e-04
# Epoch 31/50
# 994/994 [==============================] - ETA: 0s - loss: 0.0821 - accuracy: 0.9711 - f1_score: 0.9563 - precision: 0.9720 - recall: 0.9703
# Epoch 31: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 994/994 [==============================] - 705s 709ms/step - loss: 0.0821 - accuracy: 0.9711 - f1_score: 0.9563 - precision: 0.9720 - recall: 0.9703 - val_loss: 0.1662 - val_accuracy: 0.9492 - val_f1_score: 0.9229 - val_precision: 0.9506 - val_recall: 0.9482 - lr: 2.0000e-04
# Epoch 32/50
# 994/994 [==============================] - 707s 711ms/step - loss: 0.0764 - accuracy: 0.9721 - f1_score: 0.9577 - precision: 0.9726 - recall: 0.9716 - val_loss: 0.1602 - val_accuracy: 0.9515 - val_f1_score: 0.9263 - val_precision: 0.9527 - val_recall: 0.9505 - lr: 4.0000e-05
# Epoch 33/50
# 994/994 [==============================] - 701s 705ms/step - loss: 0.0751 - accuracy: 0.9726 - f1_score: 0.9585 - precision: 0.9733 - recall: 0.9722 - val_loss: 0.1625 - val_accuracy: 0.9526 - val_f1_score: 0.9280 - val_precision: 0.9537 - val_recall: 0.9514 - lr: 4.0000e-05
# Epoch 34/50
# 994/994 [==============================] - 702s 706ms/step - loss: 0.0738 - accuracy: 0.9734 - f1_score: 0.9595 - precision: 0.9740 - recall: 0.9728 - val_loss: 0.1636 - val_accuracy: 0.9526 - val_f1_score: 0.9270 - val_precision: 0.9534 - val_recall: 0.9514 - lr: 4.0000e-05
# Epoch 35/50
# 994/994 [==============================] - 892s 898ms/step - loss: 0.0745 - accuracy: 0.9733 - f1_score: 0.9594 - precision: 0.9739 - recall: 0.9727 - val_loss: 0.1637 - val_accuracy: 0.9513 - val_f1_score: 0.9251 - val_precision: 0.9522 - val_recall: 0.9504 - lr: 4.0000e-05
# Epoch 36/50
# 994/994 [==============================] - ETA: 0s - loss: 0.0736 - accuracy: 0.9736 - f1_score: 0.9596 - precision: 0.9741 - recall: 0.9729
# Epoch 36: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 994/994 [==============================] - 1178s 1s/step - loss: 0.0736 - accuracy: 0.9736 - f1_score: 0.9596 - precision: 0.9741 - recall: 0.9729 - val_loss: 0.1613 - val_accuracy: 0.9512 - val_f1_score: 0.9263 - val_precision: 0.9523 - val_recall: 0.9502 - lr: 4.0000e-05
# Epoch 37/50
# 994/994 [==============================] - 1189s 1s/step - loss: 0.0723 - accuracy: 0.9737 - f1_score: 0.9600 - precision: 0.9742 - recall: 0.9731 - val_loss: 0.1659 - val_accuracy: 0.9527 - val_f1_score: 0.9275 - val_precision: 0.9537 - val_recall: 0.9519 - lr: 8.0000e-06
# Epoch 38/50
# 994/994 [==============================] - 743s 747ms/step - loss: 0.0717 - accuracy: 0.9740 - f1_score: 0.9602 - precision: 0.9748 - recall: 0.9735 - val_loss: 0.1613 - val_accuracy: 0.9526 - val_f1_score: 0.9273 - val_precision: 0.9538 - val_recall: 0.9519 - lr: 8.0000e-06
# Epoch 39/50
# 994/994 [==============================] - 743s 747ms/step - loss: 0.0737 - accuracy: 0.9731 - f1_score: 0.9589 - precision: 0.9737 - recall: 0.9726 - val_loss: 0.1652 - val_accuracy: 0.9527 - val_f1_score: 0.9276 - val_precision: 0.9542 - val_recall: 0.9523 - lr: 8.0000e-06
# Epoch 40/50
# 994/994 [==============================] - 1251s 1s/step - loss: 0.0725 - accuracy: 0.9735 - f1_score: 0.9596 - precision: 0.9741 - recall: 0.9730 - val_loss: 0.1643 - val_accuracy: 0.9533 - val_f1_score: 0.9289 - val_precision: 0.9541 - val_recall: 0.9517 - lr: 8.0000e-06
# Epoch 41/50
# 994/994 [==============================] - ETA: 0s - loss: 0.0728 - accuracy: 0.9734 - f1_score: 0.9594 - precision: 0.9741 - recall: 0.9728
# Epoch 41: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 994/994 [==============================] - 972s 978ms/step - loss: 0.0728 - accuracy: 0.9734 - f1_score: 0.9594 - precision: 0.9741 - recall: 0.9728 - val_loss: 0.1655 - val_accuracy: 0.9523 - val_f1_score: 0.9278 - val_precision: 0.9533 - val_recall: 0.9511 - lr: 8.0000e-06
# Epoch 42/50
# 994/994 [==============================] - 740s 744ms/step - loss: 0.0735 - accuracy: 0.9733 - f1_score: 0.9592 - precision: 0.9739 - recall: 0.9728 - val_loss: 0.1670 - val_accuracy: 0.9523 - val_f1_score: 0.9274 - val_precision: 0.9534 - val_recall: 0.9514 - lr: 1.6000e-06
# Epoch 43/50
# 994/994 [==============================] - 740s 745ms/step - loss: 0.0726 - accuracy: 0.9735 - f1_score: 0.9596 - precision: 0.9739 - recall: 0.9730 - val_loss: 0.1614 - val_accuracy: 0.9535 - val_f1_score: 0.9291 - val_precision: 0.9544 - val_recall: 0.9525 - lr: 1.6000e-06
# Epoch 44/50
# 994/994 [==============================] - 1182s 1s/step - loss: 0.0718 - accuracy: 0.9740 - f1_score: 0.9604 - precision: 0.9745 - recall: 0.9735 - val_loss: 0.1681 - val_accuracy: 0.9517 - val_f1_score: 0.9257 - val_precision: 0.9527 - val_recall: 0.9509 - lr: 1.6000e-06
# Epoch 45/50
# 994/994 [==============================] - 904s 909ms/step - loss: 0.0718 - accuracy: 0.9740 - f1_score: 0.9604 - precision: 0.9745 - recall: 0.9734 - val_loss: 0.1704 - val_accuracy: 0.9511 - val_f1_score: 0.9251 - val_precision: 0.9521 - val_recall: 0.9501 - lr: 1.6000e-06
# Epoch 46/50
# 994/994 [==============================] - ETA: 0s - loss: 0.0720 - accuracy: 0.9744 - f1_score: 0.9609 - precision: 0.9750 - recall: 0.9739
# Epoch 46: ReduceLROnPlateau reducing learning rate to 1e-06.
# 994/994 [==============================] - 747s 751ms/step - loss: 0.0720 - accuracy: 0.9744 - f1_score: 0.9609 - precision: 0.9750 - recall: 0.9739 - val_loss: 0.1654 - val_accuracy: 0.9528 - val_f1_score: 0.9280 - val_precision: 0.9542 - val_recall: 0.9524 - lr: 1.6000e-06
# Epoch 47/50
# 994/994 [==============================] - 875s 880ms/step - loss: 0.0727 - accuracy: 0.9739 - f1_score: 0.9602 - precision: 0.9744 - recall: 0.9735 - val_loss: 0.1673 - val_accuracy: 0.9527 - val_f1_score: 0.9280 - val_precision: 0.9539 - val_recall: 0.9523 - lr: 1.0000e-06
# Epoch 48/50
# 994/994 [==============================] - 1487s 1s/step - loss: 0.0716 - accuracy: 0.9737 - f1_score: 0.9600 - precision: 0.9745 - recall: 0.9730 - val_loss: 0.1692 - val_accuracy: 0.9505 - val_f1_score: 0.9240 - val_precision: 0.9517 - val_recall: 0.9499 - lr: 1.0000e-06
# Epoch 49/50
# 994/994 [==============================] - 771s 776ms/step - loss: 0.0731 - accuracy: 0.9731 - f1_score: 0.9590 - precision: 0.9736 - recall: 0.9726 - val_loss: 0.1671 - val_accuracy: 0.9513 - val_f1_score: 0.9257 - val_precision: 0.9522 - val_recall: 0.9502 - lr: 1.0000e-06
# Epoch 50/50
# 994/994 [==============================] - 729s 734ms/step - loss: 0.0721 - accuracy: 0.9738 - f1_score: 0.9600 - precision: 0.9745 - recall: 0.9732 - val_loss: 0.1649 - val_accuracy: 0.9517 - val_f1_score: 0.9260 - val_precision: 0.9527 - val_recall: 0.9507 - lr: 1.0000e-06

# %%
best_epoch = np.argmax(history.history['val_accuracy']) + 1  # Adding 1 as epochs start from 1, not 0

# Find the value of the maximum validation accuracy
best_accuracy = np.max(history.history['val_accuracy'])

print(f"The best validation accuracy was {best_accuracy:.4f} at epoch {best_epoch}")
# Out:
# The best validation accuracy was 0.9535 at epoch 43

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 3))
ax = ax.ravel()

for i, met in enumerate(['accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
# Evaluate the model on test set
test_loss, test_accuracy, test_f1, test_precision, test_recall = model.evaluate(test_generator)

# Print evaluation metrics
print(f'Test Loss: {test_loss}')
print(f'Test Accuracy: {test_accuracy}')
print(f'Test f1 score: {test_f1}')
print(f'Test Precision: {test_precision}')
print(f'Test Recall: {test_recall}')
# Out:
# 63/63 [==============================] - 39s 617ms/step - loss: 0.2267 - accuracy: 0.9315 - f1_score: 0.9313 - precision: 0.9331 - recall: 0.9305
# Test Loss: 0.22674976289272308
# Test Accuracy: 0.9315000176429749
# Test f1 score: [0.9411765  0.93473685 0.91844153 0.93098515]
# Test Precision: 0.9330659508705139
# Test Recall: 0.9304999709129333

# %%
# Generate predictions for the test set
predictions = model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)

# Get true labels for the test set
true_labels = test_generator.classes

# Ensure the true labels and predicted labels have the same length
if predicted_classes.shape[0] != true_labels.shape[0]:
    n_seq = true_labels.shape[0] // predicted_classes.shape[0]
    true_labels = np.repeat(true_labels, n_seq)

# Generate a classification report
report = classification_report(true_labels, predicted_classes, target_names=test_generator.class_indices.keys())
print(report)
# Out:
# 63/63 [==============================] - 10s 157ms/step
#               precision    recall  f1-score   support
#
#          CNV       0.91      0.98      0.94      1000
#          DME       0.99      0.89      0.93      1000
#       DRUSEN       0.96      0.88      0.92      1000
#       Normal       0.89      0.98      0.93      1000
#
#     accuracy                           0.93      4000
#    macro avg       0.93      0.93      0.93      4000
# weighted avg       0.93      0.93      0.93      4000

# %%
# import numpy as np
# from sklearn.metrics import confusion_matrix
# import seaborn as sns
# import matplotlib.pyplot as plt

# Get the true labels
true_labels = test_generator.classes

# Predict the labels using the model
predictions = model.predict(test_generator)
predicted_labels = np.argmax(predictions, axis=1)

# Compute the confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)

# Plot the confusion matrix
plt.figure(figsize=(10,7))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 63/63 [==============================] - 10s 155ms/step

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# import math

epochs = len(history.history['loss'])
batch_size = 96
train_data_size = 63588

steps_per_epoch = math.ceil(train_data_size / batch_size)
total_steps = np.arange(steps_per_epoch, epochs * steps_per_epoch + 1, steps_per_epoch)

fig, ax = plt.subplots(1, 2, figsize=(10, 3))
ax = ax.ravel()

for i, met in enumerate(['accuracy', 'loss']):
    ax[i].plot(total_steps, history.history[met], '-o')
    ax[i].plot(total_steps, history.history['val_' + met], '-o')
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('steps')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])
    ax[i].set_xticks(total_steps)

# %%
model.save('C:/Users/user/projects/t81_558_deep_learning/Abletion test/Layer selection/saved models/6_layer_Abletion_v1.h5')

# %%
from sklearn.metrics import f1_score

# Get true labels for the test set
true_labels = test_generator.classes

# Generate predictions for the test set
predictions = model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)

# Compute the F1 score for each class
f1_per_class = f1_score(true_labels, predicted_classes, average=None)

# Compute the average F1 score across all classes
average_f1 = sum(f1_per_class) / len(f1_per_class)

# Print the F1 score for each class
for i, f1_class in enumerate(f1_per_class):
    print(f'F1 Score for Class {i}: {f1_class}')

# Print the average F1 score
print(f'Average F1 Score: {average_f1}')
# Out:
# 63/63 [==============================] - 10s 154ms/step
# F1 Score for Class 0: 0.9411764705882354
# F1 Score for Class 1: 0.9347368421052632
# F1 Score for Class 2: 0.9184415584415585
# F1 Score for Class 3: 0.9309852451213708
# Average F1 Score: 0.931335029064107

# %% [markdown]
# # GRADCAM

# %%
def make_gradcam_heatmap(img_array, model, last_conv_layer_name, classifier_layer_names, pred_index=None):
    # First, we create a model that maps the input image to the activations
    # of the last conv layer as well as the output predictions
    grad_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )

    # Then, we compute the gradient of the top predicted class for our input image
    # with respect to the activations of the last conv layer
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]

    # This is the gradient of the output neuron (top predicted or chosen)
    # with regard to the output feature map of the last conv layer
    grads = tape.gradient(class_channel, last_conv_layer_output)

    # This is a vector where each entry is the mean intensity of the gradient
    # over a specific feature map channel
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

# %%
# Load your image
# Specify the path to an image in your test set
img_path = 'D:/Thesis dataset/FINAL DATASET/4k_UNIQUE_Test/test/CNV/CNV-163081-230.JPEG'
 # Replace with your local image path
img = load_img(img_path, color_mode='grayscale', target_size=(224, 224))  # Set color_mode to 'grayscale'
img = img_to_array(img)

img = np.expand_dims(img, axis=0)
img = np.repeat(img, 3, axis=-1)
# img = preprocess_input(img)
img /= 255.0
# Display the image
plt.imshow(np.squeeze(img))  # Divide by 255.0 if img_rgb is scaled from 0 to 255
plt.axis('off')  # Hide the axis
plt.show()




# Predict the class (index)
preds = model.predict(img)
pred_index = np.argmax(preds[0])

# Generate class activation heatmap
last_conv_layer_name = 'Conv_4-2'  # Change to match the name of the last conv layer in your model
classifier_layer_names = []  # You may not need this for Sequential models
heatmap = make_gradcam_heatmap(img, model, last_conv_layer_name, classifier_layer_names, pred_index)

# Display heatmap
plt.matshow(heatmap)
plt.show()

# We load the original image
# We load the original grayscale image
original_img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)  # Load as grayscale

# Resize the heatmap to match the original image size
heatmap = cv2.resize(heatmap, (original_img.shape[1], original_img.shape[0]))
heatmap = np.uint8(255 * heatmap)
heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)

# Superimpose the heatmap on grayscale image
superimposed_img = cv2.cvtColor(original_img, cv2.COLOR_GRAY2BGR)  # Convert grayscale to BGR format
superimposed_img = heatmap * 0.4 + superimposed_img
superimposed_img = superimposed_img.astype('uint8')

# Superimpose the heatmap on original image
# superimposed_img = heatmap * 0.4 + original_img

# Save the image to disk
save_path = 'D:/Thesis dataset/FINAL DATASET/GRADCAM SAVED IMAGES/Ablation/6 layer/CNV-163081-230.JPEG'  # Replace with your save path
cv2.imwrite(save_path, superimposed_img)

# Display Image
plt.imshow(cv2.cvtColor(superimposed_img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 189ms/step

# %%
# Load your image

img_path ='D:/Thesis dataset/FINAL DATASET/4k_UNIQUE_Test/test/DME/DME-30521-17.jpeg'  # Replace with your local image path
img = load_img(img_path, color_mode='grayscale', target_size=(224, 224))  # Set color_mode to 'grayscale'
img = img_to_array(img)

img = np.expand_dims(img, axis=0)
img = np.repeat(img, 3, axis=-1)
# img = preprocess_input(img)
img /= 255.0
# Display the image
plt.imshow(np.squeeze(img))  # Divide by 255.0 if img_rgb is scaled from 0 to 255
plt.axis('off')  # Hide the axis
plt.show()

# Predict the class (index)
preds = model.predict(img)
pred_index = np.argmax(preds[0])

# Generate class activation heatmap
last_conv_layer_name = 'Conv_4-2'  # Change to match the name of the last conv layer in your model
classifier_layer_names = []  # You may not need this for Sequential models
heatmap = make_gradcam_heatmap(img, model, last_conv_layer_name, classifier_layer_names, pred_index)

# Display heatmap
plt.matshow(heatmap)
plt.show()

# We load the original image
# We load the original grayscale image
original_img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)  # Load as grayscale

# Resize the heatmap to match the original image size
heatmap = cv2.resize(heatmap, (original_img.shape[1], original_img.shape[0]))
heatmap = np.uint8(255 * heatmap)
heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)

# Superimpose the heatmap on grayscale image
superimposed_img = cv2.cvtColor(original_img, cv2.COLOR_GRAY2BGR)  # Convert grayscale to BGR format
superimposed_img = heatmap * 0.4 + superimposed_img
superimposed_img = superimposed_img.astype('uint8')

# Superimpose the heatmap on original image
# superimposed_img = heatmap * 0.4 + original_img

# Save the image to disk
save_path = 'D:/Thesis dataset/FINAL DATASET/GRADCAM SAVED IMAGES/Ablation/6 layer/DME-30521-17.jpeg'  # Replace with your save path
cv2.imwrite(save_path, superimposed_img)

# Display Image
plt.imshow(cv2.cvtColor(superimposed_img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 19ms/step

# %%
# Load your image

img_path ='D:/Thesis dataset/FINAL DATASET/4k_UNIQUE_Test/test/DRUSEN/DRUSEN-95633-23.jpeg'  # Replace with your local image path
img = load_img(img_path, color_mode='grayscale', target_size=(224, 224))  # Set color_mode to 'grayscale'
img = img_to_array(img)

img = np.expand_dims(img, axis=0)
img = np.repeat(img, 3, axis=-1)
# img = preprocess_input(img)
img /= 255.0
# Display the image
plt.imshow(np.squeeze(img))  # Divide by 255.0 if img_rgb is scaled from 0 to 255
plt.axis('off')  # Hide the axis
plt.show()

# Predict the class (index)
preds = model.predict(img)
pred_index = np.argmax(preds[0])

# Generate class activation heatmap
last_conv_layer_name = 'Conv_4-2'  # Change to match the name of the last conv layer in your model
classifier_layer_names = []  # You may not need this for Sequential models
heatmap = make_gradcam_heatmap(img, model, last_conv_layer_name, classifier_layer_names, pred_index)

# Display heatmap
plt.matshow(heatmap)
plt.show()

# We load the original image
# We load the original grayscale image
original_img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)  # Load as grayscale

# Resize the heatmap to match the original image size
heatmap = cv2.resize(heatmap, (original_img.shape[1], original_img.shape[0]))
heatmap = np.uint8(255 * heatmap)
heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)

# Superimpose the heatmap on grayscale image
superimposed_img = cv2.cvtColor(original_img, cv2.COLOR_GRAY2BGR)  # Convert grayscale to BGR format
superimposed_img = heatmap * 0.4 + superimposed_img
superimposed_img = superimposed_img.astype('uint8')

# Superimpose the heatmap on original image
# superimposed_img = heatmap * 0.4 + original_img

# Save the image to disk
save_path ='D:/Thesis dataset/FINAL DATASET/GRADCAM SAVED IMAGES/Ablation/6 layer/DRUSEN-95633-23.jpeg'  # Replace with your save path
cv2.imwrite(save_path, superimposed_img)

# Display Image
plt.imshow(cv2.cvtColor(superimposed_img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 19ms/step

# %%
# Load your image
img_path = 'D:/Thesis dataset/FINAL DATASET/4k_UNIQUE_Test/test/NORMAL/NORMAL-33637-1.jpeg' # Replace with your local image path
img = load_img(img_path, color_mode='grayscale', target_size=(224, 224))  # Set color_mode to 'grayscale'
img = img_to_array(img)

img = np.expand_dims(img, axis=0)
img = np.repeat(img, 3, axis=-1)
# img = preprocess_input(img)
img /= 255.0
# Display the image
plt.imshow(np.squeeze(img))  # Divide by 255.0 if img_rgb is scaled from 0 to 255
plt.axis('off')  # Hide the axis
plt.show()

# Predict the class (index)
preds = model.predict(img)
pred_index = np.argmax(preds[0])

# Generate class activation heatmap
last_conv_layer_name = 'Conv_4-2'  # Change to match the name of the last conv layer in your model
classifier_layer_names = []  # You may not need this for Sequential models
heatmap = make_gradcam_heatmap(img, model, last_conv_layer_name, classifier_layer_names, pred_index)

# Display heatmap
plt.matshow(heatmap)
plt.show()

# We load the original image
# We load the original grayscale image
original_img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)  # Load as grayscale

# Resize the heatmap to match the original image size
heatmap = cv2.resize(heatmap, (original_img.shape[1], original_img.shape[0]))
heatmap = np.uint8(255 * heatmap)
heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)

# Superimpose the heatmap on grayscale image
superimposed_img = cv2.cvtColor(original_img, cv2.COLOR_GRAY2BGR)  # Convert grayscale to BGR format
superimposed_img = heatmap * 0.4 + superimposed_img
superimposed_img = superimposed_img.astype('uint8')

# Superimpose the heatmap on original image
# superimposed_img = heatmap * 0.4 + original_img

# Save the image to disk
save_path = 'D:/Thesis dataset/FINAL DATASET/GRADCAM SAVED IMAGES/Ablation/6 layer/NORMAL-33637-1.jpeg'  # Replace with your save path
cv2.imwrite(save_path, superimposed_img)

# Display Image
plt.imshow(cv2.cvtColor(superimposed_img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 18ms/step

# %% [markdown]
# ## (750 + 250)

# %%
input_dir = "D:/Thesis dataset/vgg16/visualization/"
train_dir = input_dir +"train/"
test_dir = input_dir +"test(750+250)/"


test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(224, 224),
        batch_size=64,
        class_mode='categorical',
        shuffle = False
)


test_loss, test_accuracy, test_f1, test_precision, test_recall = model.evaluate(test_generator)

# Print evaluation metrics
print(f'Test Loss: {test_loss}')
print(f'Test Accuracy: {test_accuracy}')
print(f'Test f1 score: {test_f1}')
print(f'Test Precision: {test_precision}')
print(f'Test Recall: {test_recall}')


# Generate predictions for the test set
predictions = model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)

# Get true labels for the test set
true_labels = test_generator.classes

# Ensure the true labels and predicted labels have the same length
if predicted_classes.shape[0] != true_labels.shape[0]:
    n_seq = true_labels.shape[0] // predicted_classes.shape[0]
    true_labels = np.repeat(true_labels, n_seq)

# Generate a classification report
report = classification_report(true_labels, predicted_classes, target_names=test_generator.class_indices.keys())
print(report)


# Get the true labels
true_labels = test_generator.classes

# Predict the labels using the model
predictions = model.predict(test_generator)
predicted_labels = np.argmax(predictions, axis=1)

# Compute the confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)

# Plot the confusion matrix
plt.figure(figsize=(10,7))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Found 4000 images belonging to 4 classes.
# 63/63 [==============================] - 52s 842ms/step - loss: 0.1295 - accuracy: 0.9550 - f1_score: 0.9549 - precision: 0.9568 - recall: 0.9535
# Test Loss: 0.12952116131782532
# Test Accuracy: 0.9549999833106995
# Test f1 score: [0.9587178  0.9618557  0.942754   0.95635307]
# Test Precision: 0.9568489789962769
# Test Recall: 0.953499972820282
# 63/63 [==============================] - 9s 145ms/step
#               precision    recall  f1-score   support
#
#          CNV       0.93      0.99      0.96      1000
#          DME       0.99      0.93      0.96      1000
#       DRUSEN       0.97      0.91      0.94      1000
#       NORMAL       0.93      0.99      0.96      1000
#
#     accuracy                           0.95      4000
#    macro avg       0.96      0.96      0.95      4000
# weighted avg       0.96      0.95      0.95      4000
#
# 63/63 [==============================] - 9s 144ms/step

# %%
from sklearn.metrics import f1_score

# Get true labels for the test set
true_labels = test_generator.classes

# Generate predictions for the test set
predictions = model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)

# Compute the F1 score for each class
f1_per_class = f1_score(true_labels, predicted_classes, average=None)

# Compute the average F1 score across all classes
average_f1 = sum(f1_per_class) / len(f1_per_class)

# Print the F1 score for each class
for i, f1_class in enumerate(f1_per_class):
    print(f'F1 Score for Class {i}: {f1_class}')

# Print the average F1 score
print(f'Average F1 Score: {average_f1}')
# Out:
# 63/63 [==============================] - 9s 145ms/step
# F1 Score for Class 0: 0.9587178241864983
# F1 Score for Class 1: 0.9618556701030928
# F1 Score for Class 2: 0.9427539969056214
# F1 Score for Class 3: 0.95635305528613
# Average F1 Score: 0.9549201366203356
